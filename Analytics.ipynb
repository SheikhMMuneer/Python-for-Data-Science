# %%
import pandas as pd
import  os

# Specify Full path to File 1st Method
movies = pd.read_csv('Movie-Ratings.csv')
movies
# Out:
#                                    Film      Genre  Rotten Tomatoes Ratings %  \
# 0                 (500) Days of Summer      Comedy                         87
# 1                           10,000 B.C.  Adventure                          9
# 2                            12 Rounds      Action                         30
# 3                             127 Hours  Adventure                         93
# 4                             17 Again      Comedy                         55
# 5                                  2012     Action                         39
# 6                            27 Dresses     Comedy                         40
# 7                      30 Days of Night     Horror                         50
# 8                    30 Minutes or Less     Comedy                         43
# 9                                 50/50     Comedy                         93
# 10                           88 Minutes      Drama                          5
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
#Columns
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film','Genre','CriticRating','AudienceRatings', \
                  'BudgetMillions','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null object
# Genre              559 non-null object
# CriticRating       559 non-null int64
# AudienceRatings    559 non-null int64
# BudgetMillions     559 non-null int64
# Year               559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions         Year
# count    559.000000       559.000000      559.000000   559.000000
# mean      47.309481        58.744186       50.236136  2009.152057
# std       26.413091        16.826887       48.731817     1.362632
# min        0.000000         0.000000        0.000000  2007.000000
# 25%       25.000000        47.000000       20.000000  2008.000000
# 50%       46.000000        58.000000       35.000000  2009.000000
# 75%       70.000000        72.000000       65.000000  2010.000000
# max       97.000000        96.000000      300.000000  2011.000000

# %%
movies.Film
# Out:
# 0                   (500) Days of Summer
# 1                             10,000 B.C.
# 2                              12 Rounds
# 3                               127 Hours
# 4                               17 Again
# 5                                    2012
# 6                              27 Dresses
# 7                        30 Days of Night
# 8                      30 Minutes or Less
# 9                                   50/50
# 10                             88 Minutes
# 11                     A Dangerous Method
# 12              A Nightmare on Elm Street
# 13                         A Serious Man
# 14      A Very Harold and Kumar Christmas
# 15                              Abduction
# 16                    Across the Universe
# 17                         Adventureland
# 18                           Albert Nobbs
# 19                    Alice in Wonderland
# 20          Alien vs. Predator -- Requiem
# 21                   Aliens in the Attic
# ...

# %%
# To Change Column Data Type
movies.Film = movies.Film.astype('category')
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null object
# CriticRating       559 non-null int64
# AudienceRatings    559 non-null int64
# BudgetMillions     559 non-null int64
# Year               559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Genre= movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null category
# CriticRating       559 non-null int64
# AudienceRatings    559 non-null int64
# BudgetMillions     559 non-null int64
# Year               559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
# To know unoque values of Genre
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
#Year column no longer included as it is of category type
# Out:
#        CriticRating  AudienceRatings  BudgetMillions
# count    559.000000       559.000000      559.000000
# mean      47.309481        58.744186       50.236136
# std       26.413091        16.826887       48.731817
# min        0.000000         0.000000        0.000000
# 25%       25.000000        47.000000       20.000000
# 50%       46.000000        58.000000       35.000000
# 75%       70.000000        72.000000       65.000000
# max       97.000000        96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#JoinPlot
j = sns.jointplot(data=movies,x = 'CriticRating',y='AudienceRatings')

# %%
#JoinPlot
j = sns.jointplot(data=movies,x = 'CriticRating',y='AudienceRatings',kind='hex')

# %%
#Chart 1
m1 = sns.distplot(movies.AudienceRatings,bins=15)

# %%
#Chart 1
sns.set_style("darkgrid")
m2 = sns.distplot(movies.CriticRating,bins=16)

# %%
#Histogram
sns.set_style("white")
n1 = plt.hist(movies.CriticRating,bins=16)

# %%
#Stack Histogram
plt.hist(movies.BudgetMillions)
plt.show()

# %%
movies[movies.Genre == 'Action']
# Out:
#                                           Film   Genre  CriticRating  \
# 2                                   12 Rounds   Action            30
# 5                                         2012  Action            39
# 15                                   Abduction  Action             4
# 29                                   Appaloosa  Action            77
# 30                                    Armored   Action            40
# 33                                     Avatar   Action            83
# 36                                Babylon A.D.  Action             7
# 39                           Bangkok Dangerous  Action             9
# 40                         Battle: Los Angeles  Action            35
# 45                                     Beowulf  Action            71
# 49                                Body of Lies  Action            53
# 52                           Brooklyn's Finest  Action            42
# 58          Captain America: The First Avenger  Action            78
# ...

# %%
#Histogram
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions,bins=15)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions,bins=15)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions,bins=15)
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions, \
         movies[movies.Genre == 'Drama'].BudgetMillions] ,bins=15,stacked=True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = list()
mylabel = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabel.append(gen)
    
#sns.set_style("dark")   
sns.set_style("whitegrid") 
h = plt.hist(list1,bins=15,stacked=True,rwidth=1,label=mylabel)
plt.legend()
plt.show()

# %%
list1 = list()
mylabel = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabel.append(gen)
    
#sns.set_style("dark")   
sns.set_style("whitegrid") 
fig,ax = plt.subplots()
fig.set_size_inches(11.7,8.7)
h = plt.hist(list1,bins=15,stacked=True,rwidth=1,label=mylabel)
plt.title("Movie Budget Distribution",fontsize=35,\
         color="DarkBlue",fontname="Console")
plt.ylabel("Number of Movies",fontsize=25, color="Red")
plt.xlabel("Budget",fontsize=25, color="Green")
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.legend(frameon=True,fancybox=True,shadow=True,framealpha=0.5,prop={'size':20})
plt.show()

# %%
# Chart 4  KDE pLOT
visl = sns.lmplot(data=movies,x = 'CriticRating',y='AudienceRatings',\
                  fit_reg=False,hue='Genre', \
                  size=5, aspect=1)

# %%
# KDE Plot
k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings, \
                shade=True,shade_lowest=False,cmap='Reds')

# %%
# KDE Plot
k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings,cmap='Reds')

# %%
sns.set_style("darkgrid")
k = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings)

# %%
#SubPlot
f, ax = plt.subplots(3,2)

# %%
#SubPlot
f, axes = plt.subplots(1,2 , figsize= (12,6))
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings, ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating, ax=axes[1])

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000014F9C24A8>,
# ...
#       dtype=object)

# %%
#SubPlot
f, axes = plt.subplots(2,2 , figsize= (12,6),sharex=True,sharey=True)
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings, ax=axes[1,1])
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating, ax=axes[1,0])
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
#Violin Plot
#z = sns.violinplot(data=movies,x='Genre',y='CriticRating')
z = sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating')

# %%
#w = sns.boxplot(data=movies,x='Genre',y='CriticRating')
w = sns.boxplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating')

# %%
# Facet Grid
# g = sns.FacetGrid(movies,row='Genre',hue='Genre')
g = sns.FacetGrid(movies,row='Genre',col = 'Year', hue='Genre')

# %%
plt.scatter(movies.CriticRating,movies.AudienceRatings)

# %%
g = sns.FacetGrid(movies,row='Genre',col ='Year', hue='Genre')
g = g.map(plt.scatter,'CriticRating','AudienceRatings')

# %%
g = sns.FacetGrid(movies,row='Genre',col ='Year', hue='Genre')
g = g.map(plt.hist,'BudgetMillions')

# %%
g = sns.FacetGrid(movies,row='Genre',col ='Year', hue='Genre')
kws = dict(s=50,linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter,'CriticRating','AudienceRatings',**kws)

# %%
# Controlling Axes and adding Diagonal
g = sns.FacetGrid(movies,row='Genre',col ='Year', hue='Genre')
kws = dict(s=50,linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter,'CriticRating','AudienceRatings',**kws)
k1.set(xlim=(0,100),ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((20,60),(20,60))
g.add_legend()

# %%
# Controlling Axes and adding Diagonal
g = sns.FacetGrid(movies,row='Genre',col ='Year', hue='Genre')
kws = dict(s=50,linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter,'CriticRating','AudienceRatings',**kws)
k1.set(xlim=(0,100),ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100),(0,100),c="gray",ls="--")
g.add_legend()

# %%
# Building Dashboards
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('darkgrid')
f,axes = plt.subplots(3,2,figsize=(15,15))
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,\
                 ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,\
                 ax=axes[0,1])
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                   x='Year',y='CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings, \
                shade=True,shade_lowest=False,cmap='Reds',\
                 ax=axes[1,1])
k4b = sns.kdeplot(movies.CriticRating,movies.AudienceRatings,cmap='Reds',\
                  ax=axes[1,1])
axes[2,0].hist(movies.CriticRating,bins=15)

n4 = sns.distplot(movies.AudienceRatings,bins=15,ax=axes[2,1])

plt.show()

# %%
#Styling Dashboard
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('dark',{"axes.facecolor":"black"})
f,axes = plt.subplots(3,2,figsize=(15,15))

#Plot[0,0]
#k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,\
#                 shade=True,shade_lowest=True,cmap='Blues',\
#                 ax=axes[0,0])
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,\
                 shade=True,shade_lowest=True,cmap='inferno',\
                 ax=axes[0,0])
        
#Plot[0,0]
#k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,\
#                 cmap='Blues',ax=axes[0,1])
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,\
                 cmap='cool',ax=axes[0,1])
    
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

#Plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                   x='Year',y='BudgetMillions',palette='YlOrRd', ax=axes[1,0])

#Plot[1,1]
k4 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings, \
                shade=True,shade_lowest=False,cmap='gist_gray_r',\
                 ax=axes[1,1])
k4b = sns.kdeplot(movies.CriticRating,movies.AudienceRatings,cmap='Reds',\
                  ax=axes[1,1])
axes[2,0].hist(movies.CriticRating,bins=15)

n4 = sns.distplot(movies.AudienceRatings,bins=15,ax=axes[2,1])

plt.show()
